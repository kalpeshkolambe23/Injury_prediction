# %%
import pandas as pd
import numpy as np
import re
import datetime
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns

# %%
df = pd.read_csv('dataset.csv')

# %%
df.head()
# Out:
#             p_id2  start_year  season_days_injured  total_days_injured  \
# 0   aaronconnolly        2019                   13                 161
# 1   aaronconnolly        2020                   71                 161
# 2  aaroncresswell        2016                   95                 226
# 3  aaroncresswell        2018                   87                 226
# 4  aaroncresswell        2019                   35                 226
#
#    season_minutes_played  season_games_played  season_matches_in_squad  \
# 0                 1312.0                   24                       28
# 1                  836.0                   17                       28
# 2                 2247.0                   26                       27
# 3                 1680.0                   20                       27
# 4                 2870.0                   31                       31
#
#    total_minutes_played  total_games_played         dob  ...  \
# 0                2148.0                  41  2000-01-28  ...
# 1                2148.0                  41  2000-01-28  ...
# 2               13368.0                 149  1989-12-15  ...
# 3               13368.0                 149  1989-12-15  ...
# 4               13368.0                 149  1989-12-15  ...
#
#    cumulative_games_played  minutes_per_game_prev_seasons  \
# 0                      NaN                            NaN
# 1                     24.0                      54.666667
# 2                      NaN                            NaN
# 3                     26.0                      86.423077
# 4                     46.0                      85.369565
#
#   avg_days_injured_prev_seasons avg_games_per_season_prev_seasons        bmi  \
# 0                           NaN                               NaN  24.613627
# 1                          13.0                              24.0  24.613627
# 2                           NaN                               NaN  22.396079
# 3                          95.0                              26.0  22.396079
# 4                          91.0                              23.0  22.396079
#
#    work_rate_numeric  position_numeric significant_injury_prev_season  \
# 0                2.5               2.0                            NaN
# 1                2.5               2.0                            0.0
# 2                3.5               1.0                            NaN
# 3                3.5               1.0                            0.0
# 4                3.5               1.0                            0.0
#
#    cumulative_days_injured  season_days_injured_prev_season
# 0                      NaN                              NaN
# 1                    161.0                             13.0
# 2                      NaN                              NaN
# 3                    226.0                             95.0
# 4                    452.0                             87.0
#
# [5 rows x 30 columns]

# %%
df.iloc[4]
# Out:
# p_id2                                aaroncresswell
# start_year                                     2019
# season_days_injured                              35
# total_days_injured                              226
# season_minutes_played                        2870.0
# season_games_played                              31
# season_matches_in_squad                          31
# total_minutes_played                        13368.0
# total_games_played                              149
# dob                                      1989-12-15
# height_cm                                171.666667
# weight_kg                                      66.0
# nationality                                 England
# work_rate                               High/Medium
# pace                                      74.333333
# physic                                         67.0
# fifa_rating                               75.333333
# position                                   Defender
# age                                              30
# cumulative_minutes_played                    3927.0
# cumulative_games_played                        46.0
# minutes_per_game_prev_seasons             85.369565
# avg_days_injured_prev_seasons                  91.0
# avg_games_per_season_prev_seasons              23.0
# bmi                                       22.396079
# work_rate_numeric                               3.5
# position_numeric                                1.0
# significant_injury_prev_season                  0.0
# cumulative_days_injured                       452.0
# season_days_injured_prev_season                87.0
# Name: 4, dtype: object

# %%
df.loc[4,'work_rate']
# Out:
# 'High/Medium'

# %%
df.shape
# Out:
# (1301, 30)

# %%
df.columns
# Out:
# Index(['p_id2', 'start_year', 'season_days_injured', 'total_days_injured',
#        'season_minutes_played', 'season_games_played',
#        'season_matches_in_squad', 'total_minutes_played', 'total_games_played',
#        'dob', 'height_cm', 'weight_kg', 'nationality', 'work_rate', 'pace',
#        'physic', 'fifa_rating', 'position', 'age', 'cumulative_minutes_played',
#        'cumulative_games_played', 'minutes_per_game_prev_seasons',
#        'avg_days_injured_prev_seasons', 'avg_games_per_season_prev_seasons',
#        'bmi', 'work_rate_numeric', 'position_numeric',
#        'significant_injury_prev_season', 'cumulative_days_injured',
#        'season_days_injured_prev_season'],
#       dtype='object')

# %%
df.position.unique()
# Out:
# array(['Forward', 'Defender', 'Midfielder', 'Goalkeeper', nan],
#       dtype=object)

# %%
df.isnull().sum()
# Out:
# p_id2                                  0
# start_year                             0
# season_days_injured                    0
# total_days_injured                     0
# season_minutes_played                  0
# season_games_played                    0
# season_matches_in_squad                0
# total_minutes_played                   0
# total_games_played                     0
# dob                                    0
# height_cm                              0
# weight_kg                              0
# nationality                            0
# work_rate                              0
# pace                                  95
# physic                                95
# fifa_rating                            0
# position                               2
# age                                    0
# cumulative_minutes_played            604
# cumulative_games_played              604
# minutes_per_game_prev_seasons        616
# avg_days_injured_prev_seasons        604
# avg_games_per_season_prev_seasons    604
# bmi                                    0
# work_rate_numeric                      0
# position_numeric                       2
# significant_injury_prev_season       604
# cumulative_days_injured              604
# season_days_injured_prev_season      604
# dtype: int64

# %% [markdown]
# # analysis

# %%
'''

physical_features = ['p_id2', 'start_year', 'position', 'age',
                     'bmi', 'height_cm', 'weight_kg', 'work_rate_numeric' ,'pace', 'physic',
                     'work_rate', 'position_numeric' ,'season_days_injured']

season_features = ['p_id2', 'start_year', 'cumulative_minutes_played','cumulative_games_played',
                   'minutes_per_game_prev_seasons','avg_days_injured_prev_seasons', 'avg_games_per_season_prev_seasons', 
                  'significant_injury_prev_season', 'cumulative_days_injured','season_days_injured_prev_season',
                   'season_days_injured']

df_physical = df[physical_features]
df_season = df[season_features]



df_season.head()
'''
# Out:
# "\n\nphysical_features = ['p_id2', 'start_year', 'position', 'age',\n                     'bmi', 'height_cm', 'weight_kg', 'work_rate_numeric' ,'pace', 'physic',\n                     'work_rate', 'position_numeric' ,'season_days_injured']\n\nseason_features = ['p_id2', 'start_year', 'cumulative_minutes_played','cumulative_games_played',\n                   'minutes_per_game_prev_seasons','avg_days_injured_prev_seasons', 'avg_games_per_season_prev_seasons', \n                  'significant_injury_prev_season', 'cumulative_days_injured','season_days_injured_prev_season',\n                   'season_days_injured']\n\ndf_physical = df[physical_features]\ndf_season = df[season_features]\n\n\n\ndf_season.head()\n"

# %% [markdown]
# ploting histogram for all the columns

# %%
_ = df[df.columns].hist(bins=50, figsize=(15, 15))

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


df = pd.DataFrame(df)


selected_feature = 'season_days_injured'


correlations = df.corrwith(df[selected_feature])


plt.figure(figsize=(10, 8))
correlations.plot(kind='bar', color='skyblue')
plt.title(f'Correlation with {selected_feature}')
plt.xlabel('Features')
plt.ylabel('Correlation Coefficient')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


df = pd.DataFrame(df)


selected_feature = 'total_days_injured'


correlations = df.corrwith(df[selected_feature])


plt.figure(figsize=(10,8))
correlations.plot(kind='bar', color='skyblue')
plt.title(f'Correlation with {selected_feature}')
plt.xlabel('Features')
plt.ylabel('Correlation Coefficient')
plt.show()

# %% [markdown]
# to check the injury for prev sension

# %%
import matplotlib.pyplot as plt

df_nonulls = df.dropna()

plt.figure(figsize=(8, 6))
plt.boxplot([df_nonulls.loc[df_nonulls['significant_injury_prev_season'] == 0, 'season_days_injured'], 
             df_nonulls.loc[df_nonulls['significant_injury_prev_season'] == 1, 'season_days_injured']])
plt.xticks([1, 2], ['No significant injury', 'Significant injury'])
plt.ylabel('Season days injured')
plt.show()

# %% [markdown]
# to check season days injured by position

# %%
import matplotlib.pyplot as plt

grouped = df.groupby('position')['season_days_injured'].median()

plt.bar(grouped.index, grouped.values)
plt.title('Median Season Days Injured by Position')
plt.xlabel('Position')
plt.ylabel('Median Season Days Injured')
plt.show()

# %%
#injury threshold
injury_threshold = 120
df['target_major_injury'] = (df['season_days_injured'] > injury_threshold).astype('category')

# %%
df['target_major_injury'].value_counts()
# Out:
# False    1029
# True      272
# Name: target_major_injury, dtype: int64

# %% [markdown]
# # to check the outliers in each col

# %% [markdown]
# function to plot box plot

# %%
#Box plot function
def plot_features_vs_target_boxplot(df, x_features, y_feature):
    df_nonulls = df.dropna()

    # Generate box plots for each numerical column against the target feature
    plt.figure(figsize=(15, 15))
    for i, column in enumerate(x_features, 1):
        plt.subplot(3, 3, i)
        df_nonulls.boxplot(column=[column], by=y_feature, ax=plt.gca())
        plt.title(column)

    plt.tight_layout()
    plt.show()

# %% [markdown]
# box plot of physical features

# %%
physical_features = ['age','bmi', 'height_cm', 'weight_kg', 'work_rate_numeric' ,'pace', 'physic']

plot_features_vs_target_boxplot(df, physical_features, 'target_major_injury')

# %% [markdown]
# box plot of other features

# %%
season_features = ['cumulative_minutes_played','cumulative_games_played',
                   'minutes_per_game_prev_seasons','avg_days_injured_prev_seasons', 'avg_games_per_season_prev_seasons', 
                  'significant_injury_prev_season', 'cumulative_days_injured','season_days_injured_prev_season']

plot_features_vs_target_boxplot(df, season_features, 'target_major_injury')

# %% [markdown]
# # removing null values

# %% [markdown]
# to drop null values

# %%
#Drop nulls in key columns
cols_to_drop_nulls = [
    'cumulative_minutes_played', 'minutes_per_game_prev_seasons',
    'avg_days_injured_prev_seasons', 'significant_injury_prev_season',
    'cumulative_days_injured'
]

df = df.dropna(subset=cols_to_drop_nulls)

# %% [markdown]
# drop null values using imputer

# %%
#Impute other nulls with mean 
from sklearn.impute import SimpleImputer
mean_imputer = SimpleImputer(strategy='mean')
df[['pace', 'physic']] = mean_imputer.fit_transform(df[['pace', 'physic']])

#Impute other nulls with most frequent

mode_imputer = SimpleImputer(strategy='most_frequent')
df['position_numeric'] = mode_imputer.fit_transform(df['position_numeric'].values.reshape(-1, 1))

# %% [markdown]
# # feature selection

# %%
correlation_matrix = df.corr()

plt.figure(figsize=(10,10))
sns.heatmap(correlation_matrix, cmap='coolwarm', annot=False, linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %%
df.head()
# Out:
#             p_id2  start_year  season_days_injured  total_days_injured  \
# 1   aaronconnolly        2020                   71                 161
# 3  aaroncresswell        2018                   87                 226
# 4  aaroncresswell        2019                   35                 226
# 5  aaroncresswell        2020                    9                 226
# 7     aaronlennon        2018                  166                 199
#
#    season_minutes_played  season_games_played  season_matches_in_squad  \
# 1                  836.0                   17                       28
# 3                 1680.0                   20                       27
# 4                 2870.0                   31                       31
# 5                 3342.0                   36                       36
# 7                 1279.0                   16                       16
#
#    total_minutes_played  total_games_played         dob  ...  \
# 1                2148.0                  41  2000-01-28  ...
# 3               13368.0                 149  1989-12-15  ...
# 4               13368.0                 149  1989-12-15  ...
# 5               13368.0                 149  1989-12-15  ...
# 7                4371.0                  72  1987-04-16  ...
#
#    minutes_per_game_prev_seasons  avg_days_injured_prev_seasons  \
# 1                      54.666667                      13.000000
# 3                      86.423077                      95.000000
# 4                      85.369565                      91.000000
# 5                      88.272727                      72.333333
# 7                      68.827586                      33.000000
#
#   avg_games_per_season_prev_seasons        bmi  work_rate_numeric  \
# 1                         24.000000  24.613627                2.5
# 3                         26.000000  22.396079                3.5
# 4                         23.000000  22.396079                3.5
# 5                         25.666667  22.396079                3.5
# 7                         29.000000  23.140496                4.0
#
#    position_numeric  significant_injury_prev_season cumulative_days_injured  \
# 1               2.0                             0.0                   161.0
# 3               1.0                             0.0                   226.0
# 4               1.0                             0.0                   452.0
# 5               1.0                             0.0                   678.0
# 7               3.0                             0.0                   199.0
#
#    season_days_injured_prev_season  target_major_injury
# 1                             13.0                False
# 3                             95.0                False
# 4                             87.0                False
# 5                             35.0                False
# 7                             33.0                 True
#
# [5 rows x 31 columns]

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()

df['target_major_injury_encoded'] = label_encoder.fit_transform(df['target_major_injury'])
selected_feature = 'target_major_injury_encoded'
correlations = df.corrwith(df[selected_feature])

positive_correlations = correlations[correlations > 0]

positive_feature_names = positive_correlations.index.to_numpy()

# Plotting
plt.figure(figsize=(10, 8))
correlations.plot(kind='bar', color='skyblue')
plt.title(f'Correlation with {selected_feature}')
plt.xlabel('Features')
plt.ylabel('Correlation Coefficient')
plt.show()

# %%
positive_correlations
# Out:
# season_days_injured                0.811022
# total_days_injured                 0.378538
# weight_kg                          0.019129
# physic                             0.011302
# age                                0.051705
# cumulative_minutes_played          0.021058
# cumulative_games_played            0.027408
# avg_days_injured_prev_seasons      0.072810
# bmi                                0.032143
# position_numeric                   0.037610
# significant_injury_prev_season     0.193772
# cumulative_days_injured            0.157246
# season_days_injured_prev_season    0.147224
# target_major_injury_encoded        1.000000
# dtype: float64

# %%
positive_feature_names
# Out:
# array(['season_days_injured', 'total_days_injured', 'weight_kg', 'physic',
#        'age', 'cumulative_minutes_played', 'cumulative_games_played',
#        'avg_days_injured_prev_seasons', 'bmi', 'position_numeric',
#        'significant_injury_prev_season', 'cumulative_days_injured',
#        'season_days_injured_prev_season', 'target_major_injury_encoded'],
#       dtype=object)

# %%
#Dataset for Y as a categorical variable
df_model_cat = df[['p_id2', 'start_year', 'height_cm', 'weight_kg', 'work_rate_numeric', 'pace',
       'physic', 'position_numeric', 'age', 'cumulative_minutes_played','minutes_per_game_prev_seasons',
       'avg_days_injured_prev_seasons', 'significant_injury_prev_season', 'cumulative_days_injured',
               'target_major_injury' ]]

# %%
print('Total rows:', df_model_cat.shape[0])
# Out:
# Total rows: 685

# %%
import pandas as pd

# Assuming df_model_cat is your DataFrame
# Filter rows where 'target_major_injury' is 1 and 'position_numeric' is 1.0
filtered_df = df_model_cat[(df_model_cat['target_major_injury'] == 0) & (df_model_cat['position_numeric'] == 3.0)]



print("Filtered DataFrame:")
# Out:
# Filtered DataFrame:

# %%
filtered_df.describe()
# Out:
#         start_year   height_cm   weight_kg  work_rate_numeric        pace  \
# count   173.000000  173.000000  173.000000         173.000000  173.000000
# mean   2018.739884  179.320231   73.937476           3.491329   70.894316
# std       1.087174    6.477940    6.136161           0.408749    9.873479
# min    2016.000000  163.000000   61.333333           2.500000   46.333333
# 25%    2018.000000  175.000000   70.000000           3.000000   62.833333
# 50%    2019.000000  179.500000   73.500000           3.500000   72.000000
# 75%    2020.000000  183.666667   77.833333           4.000000   78.333333
# max    2020.000000  197.000000   90.333333           4.000000   89.000000
#
#            physic  position_numeric         age  cumulative_minutes_played  \
# count  173.000000             173.0  173.000000                 173.000000
# mean    70.042293               3.0   27.219653                3541.098266
# std      9.112917               0.0    3.430077                3219.448697
# min     46.000000               3.0   19.000000                   7.000000
# 25%     63.833333               3.0   25.000000                1544.000000
# 50%     73.166667               3.0   27.000000                2683.000000
# 75%     75.833333               3.0   30.000000                4824.000000
# max     88.166667               3.0   37.000000               24172.000000
#
#        minutes_per_game_prev_seasons  avg_days_injured_prev_seasons  \
# count                     173.000000                     173.000000
# mean                       71.746896                      71.289474
# std                        16.817255                      63.440407
# min                         7.000000                       2.000000
# 25%                        60.888889                      26.000000
# 50%                        75.034483                      52.000000
# 75%                        85.031746                      99.500000
# max                        95.000000                     337.000000
#
#        significant_injury_prev_season  cumulative_days_injured
# count                      173.000000               173.000000
# mean                         0.184971               570.034682
# std                          0.389401               814.386007
# min                          0.000000                 7.000000
# 25%                          0.000000               163.000000
# 50%                          0.000000               304.000000
# 75%                          0.000000               654.000000
# max                          1.000000              6290.000000

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming df_model_cat is your DataFrame

# Iterate through positions from 0 to 3
for position in range(4):
    for target_value in [0, 1]:
        # Filter rows where 'target_major_injury' matches the target_value and 'position_numeric' matches the current position
        filtered_df = df_model_cat[(df_model_cat['target_major_injury'] == target_value) & (df_model_cat['position_numeric'] == position)]

        # Generate descriptive statistics for the filtered DataFrame
        stats = filtered_df.describe()

        # Get the 75th percentile values for different columns
        percentile_75 = stats.loc['75%']

        # Exclude 'target_major_injury' and 'position_numeric' from plotting
        exclude_cols = ['target_major_injury', 'position_numeric']
        cols_to_plot = [col for col in percentile_75.index if col not in exclude_cols]

        # Plotting the 75th percentile values for different columns
        plt.figure(figsize=(10, 6))
        bars = percentile_75[cols_to_plot].plot(kind='bar', color='blue')
        plt.title(f"75th Percentile Values for Position {position} and Target {target_value}")
        plt.xlabel("Columns")
        plt.ylabel("75th Percentile Value")
        plt.xticks(rotation=45, ha='right')
        plt.tight_layout()

        # Annotate each bar with its corresponding value
        for bar in bars.patches:
            yval = round(bar.get_height(), 2)
            plt.text(bar.get_x() + bar.get_width() / 2, yval + 0.01, yval, ha='center', va='bottom')

        plt.show()

# %% [markdown]
# # train test split

# %%
from sklearn.model_selection import train_test_split

X = df_model_cat.drop(['target_major_injury', 'p_id2', 'start_year'], axis=1)
y = df_model_cat['target_major_injury']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
a = df_model_cat['target_major_injury']==0

# %%
row_values = df_model_cat.iloc[7, :].tolist()
print(row_values)
# Out:
# ['aaronramsey', 2016, 181.0, 74.0, 4.0, 68.16666666666667, 74.66666666666667, 3.0, 26, 1329.0, 57.78260869565217, 122.0, 1.0, 436.0, True]

# %% [markdown]
# # to avoid Oversampling

# %%
from sklearn.preprocessing import LabelEncoder
from imblearn.over_sampling import SMOTE

# Convert non-numeric labels to numeric values (required for SMOTE)
le = LabelEncoder()
y_train = le.fit_transform(y_train)

# Apply SMOTE oversampling
smote = SMOTE(random_state=42)
X_train, y_train = smote.fit_resample(X_train, y_train)

# %%
#pip install imbalanced-learn

# %% [markdown]
# # model selection

# %%
from sklearn.model_selection import train_test_split, RandomizedSearchCV, cross_val_score
from sklearn.model_selection import GridSearchCV


from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from xgboost import XGBClassifier
from catboost import CatBoostClassifier
import xgboost as xgb
from sklearn import svm

from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, precision_score, recall_score, f1_score,  roc_auc_score


# import warnings

# %%
classification_models = {
    "Logistic Regression": LogisticRegression(),
    "K-Nearest Neighbors": KNeighborsClassifier(),
    "Decision Tree Classifier": DecisionTreeClassifier(max_depth=7),
    "Random Forest Classifier": RandomForestClassifier(),
    "XGBoost Classifier": XGBClassifier(),
    "CatBoost Classifier": CatBoostClassifier(verbose=False),
    "AdaBoost Classifier": AdaBoostClassifier()
    
}

for model_name, model in classification_models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)

    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    report = classification_report(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    #f1_score = f1_score(y_test, y_pred)
    roc_auc = roc_auc_score(y_test, y_pred)

    print(f"Model: {model_name}")
    print(f"Accuracy: {accuracy:.5f}")
    print(f"precision: {precision:.5f}")
    print(f"recall: {recall:.5f}")
    #print("F1 score: {:.2f}%".format(f1_score*100))
    print(f"roc_auc: {roc_auc:.5f}")
    print('***********************************')
    
    print(f"Classification Report:\n{report}\n")
# Out:
# C:\python3.10.1\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Model: Logistic Regression
# Accuracy: 0.64563
# precision: 0.23188
# recall: 0.44444
# roc_auc: 0.56634
# ***********************************
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.69      0.76       170
#          1.0       0.23      0.44      0.30        36
#
#     accuracy                           0.65       206
#    macro avg       0.54      0.57      0.53       206
# weighted avg       0.75      0.65      0.68       206
#
#
# Model: K-Nearest Neighbors
# Accuracy: 0.65049
# precision: 0.26316
# recall: 0.55556
# roc_auc: 0.61307
# ***********************************
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.67      0.76       170
#          1.0       0.26      0.56      0.36        36
#
#     accuracy                           0.65       206
#    macro avg       0.57      0.61      0.56       206
# weighted avg       0.77      0.65      0.69       206
#
#
# Model: Decision Tree Classifier
# Accuracy: 0.59223
# precision: 0.21429
# recall: 0.50000
# roc_auc: 0.55588
# ***********************************
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.61      0.71       170
#          1.0       0.21      0.50      0.30        36
#
#     accuracy                           0.59       206
#    macro avg       0.53      0.56      0.51       206
# weighted avg       0.74      0.59      0.64       206
#
#
# Model: Random Forest Classifier
# Accuracy: 0.72816
# precision: 0.18750
# recall: 0.16667
# roc_auc: 0.50686
# ***********************************
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.83      0.85      0.84       170
#          1.0       0.19      0.17      0.18        36
#
#     accuracy                           0.73       206
#    macro avg       0.51      0.51      0.51       206
# weighted avg       0.72      0.73      0.72       206
#
#
# Model: XGBoost Classifier
# Accuracy: 0.75243
# precision: 0.29730
# recall: 0.30556
# roc_auc: 0.57631
# ***********************************
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.85      0.85       170
#          1.0       0.30      0.31      0.30        36
#
#     accuracy                           0.75       206
#    macro avg       0.57      0.58      0.58       206
# weighted avg       0.76      0.75      0.75       206
#
#
# Model: CatBoost Classifier
# Accuracy: 0.76214
# precision: 0.31429
# recall: 0.30556
# roc_auc: 0.58219
# ***********************************
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.86      0.86       170
#          1.0       0.31      0.31      0.31        36
#
#     accuracy                           0.76       206
#    macro avg       0.58      0.58      0.58       206
# weighted avg       0.76      0.76      0.76       206
#
#
# Model: AdaBoost Classifier
# Accuracy: 0.71845
# precision: 0.22500
# recall: 0.25000
# roc_auc: 0.53382
# ***********************************
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.84      0.82      0.83       170
#          1.0       0.23      0.25      0.24        36
#
#     accuracy                           0.72       206
#    macro avg       0.53      0.53      0.53       206
# weighted avg       0.73      0.72      0.72       206

# %%
'''

results_df = pd.DataFrame(columns=["Model", "Accuracy", "Precision", " roc_auc"])

for model_name, model in classification_models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)

    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    roc_auc = roc_auc_score(y_test, y_pred)


    results_df = results_df.append({
        "Model": model_name,
        "Accuracy": accuracy,
        "Precision": precision,
        "Recall" : recall,
        "F1 Score" : f1,
        "ROC AUC" : roc_auc
    }, ignore_index=True)

print(results_df)

'''
# Out:
# '\n\nresults_df = pd.DataFrame(columns=["Model", "Accuracy", "Precision", " roc_auc"])\n\nfor model_name, model in classification_models.items():\n    model.fit(X_train, y_train)\n    y_pred = model.predict(X_test)\n\n    accuracy = accuracy_score(y_test, y_pred)\n    precision = precision_score(y_test, y_pred)\n    recall = recall_score(y_test, y_pred)\n    f1 = f1_score(y_test, y_pred)\n    roc_auc = roc_auc_score(y_test, y_pred)\n\n\n    results_df = results_df.append({\n        "Model": model_name,\n        "Accuracy": accuracy,\n        "Precision": precision,\n        "Recall" : recall,\n        "F1 Score" : f1,\n        "ROC AUC" : roc_auc\n    }, ignore_index=True)\n\nprint(results_df)\n\n'

# %%
'''
xgb_clf = xgb.XGBClassifier(
    n_estimators=100, learning_rate=0.1, max_depth=3, random_state=42, use_label_encoder=False
)

# Fit the model to the training data
xgb_clf.fit(X_train, y_train, eval_metric='auc')

# Make predictions on the test set
y_pred_proba = xgb_clf.predict_proba(X_test)[:, 1]

# Compute ROC AUC score
roc_auc = roc_auc_score(y_test, y_pred_proba)
print("ROC AUC score:", roc_auc)

'''
# Out:
# '\nxgb_clf = xgb.XGBClassifier(\n    n_estimators=100, learning_rate=0.1, max_depth=3, random_state=42, use_label_encoder=False\n)\n\n# Fit the model to the training data\nxgb_clf.fit(X_train, y_train, eval_metric=\'auc\')\n\n# Make predictions on the test set\ny_pred_proba = xgb_clf.predict_proba(X_test)[:, 1]\n\n# Compute ROC AUC score\nroc_auc = roc_auc_score(y_test, y_pred_proba)\nprint("ROC AUC score:", roc_auc)\n\n'

# %% [markdown]
# # hyperparameter tunning

# %% [markdown]
# 1] for xgboost classifier

# %%
xgb_model = XGBClassifier()
from sklearn.model_selection import GridSearchCV

# Define the hyperparameter grid
param_grid = {
    'learning_rate': [0.01, 0.1, 0.2],
    'n_estimators': [50, 100, 200],
    'max_depth': [3, 5, 7],
    'min_child_weight': [1, 3, 5],
    'gamma': [0, 0.1, 0.2],
    'subsample': [0.8, 0.9, 1.0],
    'colsample_bytree': [0.8, 0.9, 1.0],
    'scale_pos_weight': [1, 2, 3]
}

# Create the GridSearchCV object
grid_search = GridSearchCV(
    xgb_model,
    param_grid=param_grid,
    scoring='accuracy',
    cv=5,
    n_jobs=-1
)

# Fit the model to the training data with grid search
grid_search.fit(X_train, y_train)

# Get the best parameters
best_params = grid_search.best_params_

# Use the best model to make predictions
best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test)

# Evaluate the best model
accuracy = accuracy_score(y_test, y_pred)
print(f"Best Hyperparameters: {best_params}")
print(f"Accuracy: {accuracy:.5f}")
# Out:
# Best Hyperparameters: {'colsample_bytree': 1.0, 'gamma': 0.2, 'learning_rate': 0.2, 'max_depth': 5, 'min_child_weight': 1, 'n_estimators': 100, 'scale_pos_weight': 1, 'subsample': 0.8}
# Accuracy: 0.73301

# %%
best_params = grid_search.best_params_
final_xgb_clf = xgb.XGBClassifier(**best_params, random_state=42, use_label_encoder=False)
final_xgb_clf.fit(X_train, y_train, eval_metric='auc')

# Make predictions on the test set
y_pred_proba_final = final_xgb_clf.predict_proba(X_test)[:, 1]

# Compute ROC AUC score
roc_auc_final = roc_auc_score(y_test, y_pred_proba_final)
print("Final ROC AUC score:", roc_auc_final)
# Out:
# Final ROC AUC score: 0.6702614379084968
# C:\python3.10.1\lib\site-packages\xgboost\sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# C:\python3.10.1\lib\site-packages\xgboost\sklearn.py:835: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(

# %%
# CV

k = 5
cv_result = cross_val_score(xgb_model,X,y,cv=k)
print('CV Scores: ',cv_result)
print('CV scores average: ',np.sum(cv_result)/k)
# Out:
# CV Scores:  [0.80291971 0.68613139 0.72262774 0.80291971 0.79562044]
# CV scores average:  0.762043795620438

# %% [markdown]
# 2] decision tree classifier

# %%
dt_classifier = DecisionTreeClassifier()

# Define the hyperparameter grid
param_grid = {
    'criterion': ['gini', 'entropy'],
    'max_depth': [None, 5, 10, 15],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': [None, 'sqrt', 'log2']
}

# Create the GridSearchCV object
grid_search = GridSearchCV(
    dt_classifier,
    param_grid=param_grid,
    scoring='accuracy',
    cv=5,
    n_jobs=-1
)

# Fit the model to the training data with grid search
grid_search.fit(X_train, y_train)

# Get the best parameters
best_params = grid_search.best_params_

# Use the best model to make predictions
best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test)

# Evaluate the best model
accuracy = accuracy_score(y_test, y_pred)
print(f"Best Hyperparameters: {best_params}")
print(f"Accuracy: {accuracy:.5f}")
# Out:
# Best Hyperparameters: {'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 10}
# Accuracy: 0.63592

# %%
best_params = grid_search.best_params_
final_xgb_clf = DecisionTreeClassifier(**best_params, random_state=42)
final_xgb_clf.fit(X_train, y_train)

# Make predictions on the test set
y_pred_proba_final = final_xgb_clf.predict_proba(X_test)[:, 1]

# Compute ROC AUC score
roc_auc_final = roc_auc_score(y_test, y_pred_proba_final)
print("Final ROC AUC score:", roc_auc_final)
# Out:
# Final ROC AUC score: 0.5718954248366014

# %%
k = 5
cv_result = cross_val_score(dt_classifier,X,y,cv=k)
print('CV Scores: ',cv_result)
print('CV scores average: ',np.sum(cv_result)/k)
# Out:
# CV Scores:  [0.73722628 0.54744526 0.62773723 0.70072993 0.69343066]
# CV scores average:  0.6613138686131388

# %% [markdown]
# 3] k nearest neighbour

# %%
knn_model = KNeighborsClassifier()

# Define the hyperparameter grid
param_grid = {
    'n_neighbors': [3, 5, 7, 9],  # Adjust the values based on your problem
    'weights': ['uniform', 'distance'],
    'metric': ['euclidean', 'manhattan']
}

# Create the GridSearchCV object
grid_search = GridSearchCV(
    knn_model,
    param_grid=param_grid,
    scoring='accuracy',
    cv=5,
    n_jobs=-1
)

# Fit the model to the training data with grid search
grid_search.fit(X_train, y_train)

# Get the best parameters
best_params = grid_search.best_params_

# Use the best model to make predictions
best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test)

# Evaluate the best model
accuracy = accuracy_score(y_test, y_pred)
print(f"Best Hyperparameters: {best_params}")
print(f"Accuracy: {accuracy:.5f}")
# Out:
# Best Hyperparameters: {'metric': 'manhattan', 'n_neighbors': 7, 'weights': 'distance'}
# Accuracy: 0.66019

# %%
best_params = grid_search.best_params_
final_xgb_clf = KNeighborsClassifier(**best_params)
final_xgb_clf.fit(X_train, y_train)

# Make predictions on the test set
y_pred_proba_final = final_xgb_clf.predict_proba(X_test)[:, 1]

# Compute ROC AUC score
roc_auc_final = roc_auc_score(y_test, y_pred_proba_final)
print("Final ROC AUC score:", roc_auc_final)
# Out:
# Final ROC AUC score: 0.7011437908496732

# %%
X_test.columns
# Out:
# Index(['height_cm', 'weight_kg', 'work_rate_numeric', 'pace', 'physic',
#        'position_numeric', 'age', 'cumulative_minutes_played',
#        'minutes_per_game_prev_seasons', 'avg_days_injured_prev_seasons',
#        'significant_injury_prev_season', 'cumulative_days_injured'],
#       dtype='object')

# %%
k = 5
cv_result = cross_val_score(knn_model,X,y,cv=k)
print('CV Scores: ',cv_result)
print('CV scores average: ',np.sum(cv_result)/k)
# Out:
# CV Scores:  [0.72992701 0.73722628 0.77372263 0.76642336 0.72262774]
# CV scores average:  0.745985401459854

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import roc_curve, auc
from sklearn.datasets import make_classification



# Create and train the KNN classifier
knn_classifier = KNeighborsClassifier(**best_params)
knn_classifier.fit(X_train, y_train)

# Predict probabilities for the positive class
y_probabilities = knn_classifier.predict_proba(X_test)[:, 1]

# Compute ROC curve and AUC
fpr, tpr, thresholds = roc_curve(y_test, y_probabilities)
roc_auc = auc(fpr, tpr)

# Plot ROC curve
plt.figure(figsize=(4,4))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for KNN Classifier')
plt.legend(loc='lower right')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.datasets import make_classification
from sklearn.metrics import accuracy_score



# Create and train the KNN classifier
knn_classifier = KNeighborsClassifier(n_neighbors=3)
knn_classifier.fit(X_train, y_train)

# Make predictions
y_pred = knn_classifier.predict(X_test)

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy:.2f}')

# Create confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Plot confusion matrix
plt.figure(figsize=(4,4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()
# Out:
# Accuracy: 0.70

# %% [markdown]
# 4] svm

# %%
'''
from sklearn import svm
svm_model = svm.SVC()

# Define the hyperparameter grid
param_grid = {
    'C': [0.1, 1, 10, 100],
    'kernel': ['linear', 'rbf', 'poly'],
    'gamma': ['scale', 'auto', 0.1, 0.01, 0.001],
    'degree': [2, 3, 4],
    'class_weight': [None, 'balanced']
}

# Create the GridSearchCV object
grid_search = GridSearchCV(
    svm_model,
    param_grid=param_grid,
    scoring='accuracy',
    cv=5,
    n_jobs=-1
)

# Fit the model to the training data with grid search
grid_search.fit(X_train, y_train)

# Get the best parameters
best_params = grid_search.best_params_

# Use the best model to make predictions
best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test)

# Evaluate the best model
accuracy = accuracy_score(y_test, y_pred)
print(f"Best Hyperparameters: {best_params}")
print(f"Accuracy: {accuracy:.5f}")
'''
# Out:
# '\nfrom sklearn import svm\nsvm_model = svm.SVC()\n\n# Define the hyperparameter grid\nparam_grid = {\n    \'C\': [0.1, 1, 10, 100],\n    \'kernel\': [\'linear\', \'rbf\', \'poly\'],\n    \'gamma\': [\'scale\', \'auto\', 0.1, 0.01, 0.001],\n    \'degree\': [2, 3, 4],\n    \'class_weight\': [None, \'balanced\']\n}\n\n# Create the GridSearchCV object\ngrid_search = GridSearchCV(\n    svm_model,\n    param_grid=param_grid,\n    scoring=\'accuracy\',\n    cv=5,\n    n_jobs=-1\n)\n\n# Fit the model to the training data with grid search\ngrid_search.fit(X_train, y_train)\n\n# Get the best parameters\nbest_params = grid_search.best_params_\n\n# Use the best model to make predictions\nbest_model = grid_search.best_estimator_\ny_pred = best_model.predict(X_test)\n\n# Evaluate the best model\naccuracy = accuracy_score(y_test, y_pred)\nprint(f"Best Hyperparameters: {best_params}")\nprint(f"Accuracy: {accuracy:.5f}")\n'

# %%
'''
best_params = grid_search.best_params_
final_xgb_clf = svm.SVC(**best_params)
final_xgb_clf.fit(X_train, y_train)

# Make predictions on the test set
y_pred_proba_final = final_xgb_clf.predict_proba(X_test)[:, 1]

# Compute ROC AUC score
roc_auc_final = roc_auc_score(y_test, y_pred_proba_final)
print("Final ROC AUC score:", roc_auc_final)
'''
# Out:
# '\nbest_params = grid_search.best_params_\nfinal_xgb_clf = svm.SVC(**best_params)\nfinal_xgb_clf.fit(X_train, y_train)\n\n# Make predictions on the test set\ny_pred_proba_final = final_xgb_clf.predict_proba(X_test)[:, 1]\n\n# Compute ROC AUC score\nroc_auc_final = roc_auc_score(y_test, y_pred_proba_final)\nprint("Final ROC AUC score:", roc_auc_final)\n'

# %%
'''
k = 5
cv_result = cross_val_score(svm_model,X,y,cv=k)
print('CV Scores: ',cv_result)
print('CV scores average: ',np.sum(cv_result)/k)
'''
# Out:
# "\nk = 5\ncv_result = cross_val_score(svm_model,X,y,cv=k)\nprint('CV Scores: ',cv_result)\nprint('CV scores average: ',np.sum(cv_result)/k)\n"

# %% [markdown]
# 5] random forest classifier

# %%
rf_model = RandomForestClassifier()

# Define the hyperparameter grid
param_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['auto', 'sqrt', 'log2']
}

# Create the GridSearchCV object
grid_search = GridSearchCV(
    rf_model,
    param_grid=param_grid,
    scoring='accuracy',
    cv=5,
    n_jobs=-1
)

# Fit the model to the training data with grid search
grid_search.fit(X_train, y_train)

# Get the best parameters
best_params = grid_search.best_params_

# Use the best model to make predictions
best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test)

# Evaluate the best model
accuracy = accuracy_score(y_test, y_pred)
print(f"Best Hyperparameters: {best_params}")
print(f"Accuracy: {accuracy:.5f}")

# Print additional metrics or reports as needed
#print(classification_report(y_test, y_pred))
#print(confusion_matrix(y_test, y_pred))
# Out:
# Best Hyperparameters: {'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# Accuracy: 0.73301

# %%
best_params = grid_search.best_params_
final_xgb_clf = RandomForestClassifier(**best_params)
final_xgb_clf.fit(X_train, y_train)

# Make predictions on the test set
y_pred_proba_final = final_xgb_clf.predict_proba(X_test)[:, 1]

# Compute ROC AUC score
roc_auc_final = roc_auc_score(y_test, y_pred_proba_final)
print("Final ROC AUC score:", roc_auc_final)
# Out:
# Final ROC AUC score: 0.6218954248366013

# %%
k = 5
cv_result = cross_val_score(rf_model,X,y,cv=k)
print('CV Scores: ',cv_result)
print('CV scores average: ',np.sum(cv_result)/k)
# Out:
# CV Scores:  [0.81751825 0.72992701 0.76642336 0.75912409 0.77372263]
# CV scores average:  0.7693430656934306

# %% [markdown]
# 6] catboost model

# %%
catboost_model = CatBoostClassifier()

# Define the hyperparameter grid
param_grid = {
    'iterations': [100, 200, 300],
    'learning_rate': [0.01, 0.1, 0.2],
    'depth': [4, 6, 8],
    'l2_leaf_reg': [1, 3, 5],
    'border_count': [32, 64, 128]
}

# Create the GridSearchCV object
grid_search = GridSearchCV(
    catboost_model,
    param_grid=param_grid,
    scoring='accuracy',
    cv=5,
    n_jobs=-1
)

# Fit the model to the training data with grid search
grid_search.fit(X_train, y_train)

# Get the best parameters
best_params = grid_search.best_params_

# Use the best model to make predictions
best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test)

# Evaluate the best model
accuracy = accuracy_score(y_test, y_pred)
print(f"Best Hyperparameters: {best_params}")
print(f"Accuracy: {accuracy:.5f}")
# Out:
# 0:	learn: 0.6414715	total: 13.5ms	remaining: 2.69s
# 1:	learn: 0.5897174	total: 19.3ms	remaining: 1.91s
# 2:	learn: 0.5576135	total: 26ms	remaining: 1.71s
# 3:	learn: 0.5245553	total: 31.1ms	remaining: 1.52s
# 4:	learn: 0.5048667	total: 37.9ms	remaining: 1.48s
# 5:	learn: 0.4821132	total: 44.4ms	remaining: 1.44s
# 6:	learn: 0.4666344	total: 50.1ms	remaining: 1.38s
# 7:	learn: 0.4432706	total: 56.8ms	remaining: 1.36s
# 8:	learn: 0.4241402	total: 62.1ms	remaining: 1.32s
# 9:	learn: 0.4094466	total: 68.2ms	remaining: 1.29s
# 10:	learn: 0.3947041	total: 74.2ms	remaining: 1.27s
# 11:	learn: 0.3851821	total: 80.1ms	remaining: 1.25s
# 12:	learn: 0.3680709	total: 86.2ms	remaining: 1.24s
# 13:	learn: 0.3546043	total: 91.9ms	remaining: 1.22s
# 14:	learn: 0.3382709	total: 100ms	remaining: 1.24s
# 15:	learn: 0.3250368	total: 107ms	remaining: 1.23s
# 16:	learn: 0.3155018	total: 113ms	remaining: 1.21s
# 17:	learn: 0.3073458	total: 119ms	remaining: 1.2s
# 18:	learn: 0.2938923	total: 125ms	remaining: 1.19s
# 19:	learn: 0.2828936	total: 134ms	remaining: 1.21s
# 20:	learn: 0.2756567	total: 140ms	remaining: 1.2s
# 21:	learn: 0.2687469	total: 146ms	remaining: 1.18s
# 22:	learn: 0.2591120	total: 152ms	remaining: 1.17s
# 23:	learn: 0.2529230	total: 159ms	remaining: 1.16s
# 24:	learn: 0.2458878	total: 165ms	remaining: 1.16s
# 25:	learn: 0.2383706	total: 172ms	remaining: 1.15s
# 26:	learn: 0.2331885	total: 179ms	remaining: 1.15s
# 27:	learn: 0.2281785	total: 186ms	remaining: 1.14s
# 28:	learn: 0.2240049	total: 193ms	remaining: 1.14s
# 29:	learn: 0.2167594	total: 200ms	remaining: 1.13s
# 30:	learn: 0.2096263	total: 206ms	remaining: 1.13s
# 31:	learn: 0.2045769	total: 215ms	remaining: 1.13s
# 32:	learn: 0.1993412	total: 221ms	remaining: 1.11s
# 33:	learn: 0.1967287	total: 227ms	remaining: 1.11s
# 34:	learn: 0.1935504	total: 234ms	remaining: 1.1s
# 35:	learn: 0.1905784	total: 244ms	remaining: 1.11s
# 36:	learn: 0.1858356	total: 251ms	remaining: 1.11s
# 37:	learn: 0.1823626	total: 260ms	remaining: 1.11s
# 38:	learn: 0.1769441	total: 268ms	remaining: 1.1s
# 39:	learn: 0.1728184	total: 275ms	remaining: 1.1s
# 40:	learn: 0.1694429	total: 283ms	remaining: 1.1s
# 41:	learn: 0.1657740	total: 291ms	remaining: 1.09s
# 42:	learn: 0.1627024	total: 299ms	remaining: 1.09s
# 43:	learn: 0.1597701	total: 311ms	remaining: 1.1s
# 44:	learn: 0.1568477	total: 322ms	remaining: 1.11s
# 45:	learn: 0.1539229	total: 330ms	remaining: 1.1s
# 46:	learn: 0.1508843	total: 339ms	remaining: 1.1s
# 47:	learn: 0.1466386	total: 346ms	remaining: 1.09s
# 48:	learn: 0.1452192	total: 355ms	remaining: 1.09s
# 49:	learn: 0.1421802	total: 361ms	remaining: 1.08s
# 50:	learn: 0.1384874	total: 376ms	remaining: 1.1s
# 51:	learn: 0.1348230	total: 391ms	remaining: 1.11s
# 52:	learn: 0.1323699	total: 403ms	remaining: 1.12s
# 53:	learn: 0.1301843	total: 411ms	remaining: 1.11s
# 54:	learn: 0.1281072	total: 432ms	remaining: 1.14s
# 55:	learn: 0.1261667	total: 440ms	remaining: 1.13s
# 56:	learn: 0.1236145	total: 447ms	remaining: 1.12s
# 57:	learn: 0.1212931	total: 455ms	remaining: 1.11s
# 58:	learn: 0.1197410	total: 460ms	remaining: 1.1s
# 59:	learn: 0.1175645	total: 467ms	remaining: 1.09s
# 60:	learn: 0.1155198	total: 472ms	remaining: 1.07s
# 61:	learn: 0.1129876	total: 480ms	remaining: 1.07s
# 62:	learn: 0.1110535	total: 487ms	remaining: 1.06s
# 63:	learn: 0.1088450	total: 495ms	remaining: 1.05s
# 64:	learn: 0.1059702	total: 504ms	remaining: 1.05s
# 65:	learn: 0.1043828	total: 513ms	remaining: 1.04s
# 66:	learn: 0.1022559	total: 521ms	remaining: 1.03s
# 67:	learn: 0.1003052	total: 529ms	remaining: 1.03s
# 68:	learn: 0.0980851	total: 537ms	remaining: 1.02s
# 69:	learn: 0.0964813	total: 550ms	remaining: 1.02s
# 70:	learn: 0.0953261	total: 560ms	remaining: 1.02s
# 71:	learn: 0.0938500	total: 567ms	remaining: 1.01s
# 72:	learn: 0.0917911	total: 574ms	remaining: 998ms
# 73:	learn: 0.0905014	total: 583ms	remaining: 992ms
# 74:	learn: 0.0893042	total: 592ms	remaining: 986ms
# 75:	learn: 0.0877146	total: 599ms	remaining: 977ms
# 76:	learn: 0.0859979	total: 606ms	remaining: 968ms
# 77:	learn: 0.0846004	total: 611ms	remaining: 956ms
# 78:	learn: 0.0824482	total: 618ms	remaining: 946ms
# 79:	learn: 0.0805444	total: 626ms	remaining: 939ms
# 80:	learn: 0.0784587	total: 634ms	remaining: 931ms
# 81:	learn: 0.0770759	total: 640ms	remaining: 922ms
# 82:	learn: 0.0759037	total: 647ms	remaining: 912ms
# 83:	learn: 0.0745845	total: 656ms	remaining: 907ms
# 84:	learn: 0.0732926	total: 664ms	remaining: 898ms
# 85:	learn: 0.0719568	total: 673ms	remaining: 892ms
# 86:	learn: 0.0707435	total: 680ms	remaining: 883ms
# 87:	learn: 0.0699670	total: 688ms	remaining: 876ms
# 88:	learn: 0.0687304	total: 695ms	remaining: 867ms
# 89:	learn: 0.0673691	total: 703ms	remaining: 859ms
# 90:	learn: 0.0659832	total: 710ms	remaining: 851ms
# 91:	learn: 0.0648193	total: 717ms	remaining: 842ms
# 92:	learn: 0.0637926	total: 725ms	remaining: 834ms
# 93:	learn: 0.0623172	total: 733ms	remaining: 827ms
# 94:	learn: 0.0615187	total: 743ms	remaining: 821ms
# 95:	learn: 0.0606881	total: 753ms	remaining: 816ms
# 96:	learn: 0.0600132	total: 760ms	remaining: 807ms
# 97:	learn: 0.0589375	total: 769ms	remaining: 801ms
# 98:	learn: 0.0578022	total: 779ms	remaining: 795ms
# 99:	learn: 0.0567362	total: 789ms	remaining: 789ms
# 100:	learn: 0.0558226	total: 798ms	remaining: 782ms
# 101:	learn: 0.0545881	total: 804ms	remaining: 773ms
# 102:	learn: 0.0536279	total: 811ms	remaining: 764ms
# 103:	learn: 0.0527276	total: 820ms	remaining: 756ms
# 104:	learn: 0.0519828	total: 827ms	remaining: 749ms
# 105:	learn: 0.0515011	total: 838ms	remaining: 743ms
# 106:	learn: 0.0505225	total: 847ms	remaining: 736ms
# 107:	learn: 0.0496296	total: 855ms	remaining: 728ms
# 108:	learn: 0.0486759	total: 871ms	remaining: 727ms
# 109:	learn: 0.0479414	total: 878ms	remaining: 718ms
# 110:	learn: 0.0472199	total: 884ms	remaining: 709ms
# 111:	learn: 0.0461821	total: 891ms	remaining: 700ms
# 112:	learn: 0.0454179	total: 899ms	remaining: 692ms
# 113:	learn: 0.0446062	total: 905ms	remaining: 683ms
# 114:	learn: 0.0439505	total: 913ms	remaining: 675ms
# 115:	learn: 0.0434384	total: 919ms	remaining: 666ms
# 116:	learn: 0.0426311	total: 929ms	remaining: 659ms
# 117:	learn: 0.0419754	total: 939ms	remaining: 653ms
# 118:	learn: 0.0412874	total: 952ms	remaining: 648ms
# 119:	learn: 0.0406706	total: 964ms	remaining: 643ms
# 120:	learn: 0.0400134	total: 974ms	remaining: 636ms
# 121:	learn: 0.0393869	total: 981ms	remaining: 627ms
# 122:	learn: 0.0387831	total: 988ms	remaining: 619ms
# 123:	learn: 0.0380955	total: 995ms	remaining: 610ms
# 124:	learn: 0.0376414	total: 1s	remaining: 602ms
# 125:	learn: 0.0372512	total: 1.01s	remaining: 595ms
# 126:	learn: 0.0368501	total: 1.02s	remaining: 586ms
# 127:	learn: 0.0364914	total: 1.03s	remaining: 579ms
# 128:	learn: 0.0358990	total: 1.03s	remaining: 569ms
# 129:	learn: 0.0353692	total: 1.04s	remaining: 561ms
# 130:	learn: 0.0350922	total: 1.05s	remaining: 553ms
# 131:	learn: 0.0346283	total: 1.06s	remaining: 546ms
# 132:	learn: 0.0338733	total: 1.07s	remaining: 538ms
# 133:	learn: 0.0333833	total: 1.07s	remaining: 529ms
# 134:	learn: 0.0330436	total: 1.08s	remaining: 521ms
# 135:	learn: 0.0326930	total: 1.09s	remaining: 513ms
# 136:	learn: 0.0323439	total: 1.1s	remaining: 504ms
# 137:	learn: 0.0320021	total: 1.1s	remaining: 496ms
# 138:	learn: 0.0314953	total: 1.11s	remaining: 488ms
# 139:	learn: 0.0309556	total: 1.12s	remaining: 479ms
# 140:	learn: 0.0306455	total: 1.13s	remaining: 471ms
# 141:	learn: 0.0302913	total: 1.13s	remaining: 464ms
# 142:	learn: 0.0301087	total: 1.14s	remaining: 455ms
# 143:	learn: 0.0297524	total: 1.15s	remaining: 446ms
# 144:	learn: 0.0292805	total: 1.15s	remaining: 438ms
# 145:	learn: 0.0289145	total: 1.17s	remaining: 432ms
# 146:	learn: 0.0286047	total: 1.18s	remaining: 424ms
# 147:	learn: 0.0281104	total: 1.18s	remaining: 416ms
# 148:	learn: 0.0278246	total: 1.19s	remaining: 408ms
# 149:	learn: 0.0275794	total: 1.2s	remaining: 400ms
# 150:	learn: 0.0273867	total: 1.21s	remaining: 392ms
# 151:	learn: 0.0270099	total: 1.22s	remaining: 385ms
# 152:	learn: 0.0267259	total: 1.23s	remaining: 377ms
# 153:	learn: 0.0264372	total: 1.24s	remaining: 369ms
# 154:	learn: 0.0261555	total: 1.24s	remaining: 361ms
# 155:	learn: 0.0258244	total: 1.25s	remaining: 353ms
# 156:	learn: 0.0254828	total: 1.26s	remaining: 345ms
# 157:	learn: 0.0252342	total: 1.27s	remaining: 337ms
# 158:	learn: 0.0250506	total: 1.27s	remaining: 329ms
# 159:	learn: 0.0248189	total: 1.28s	remaining: 321ms
# 160:	learn: 0.0246278	total: 1.29s	remaining: 314ms
# 161:	learn: 0.0243551	total: 1.3s	remaining: 306ms
# 162:	learn: 0.0240804	total: 1.32s	remaining: 300ms
# 163:	learn: 0.0237671	total: 1.33s	remaining: 293ms
# 164:	learn: 0.0234275	total: 1.34s	remaining: 285ms
# 165:	learn: 0.0232144	total: 1.36s	remaining: 278ms
# 166:	learn: 0.0230025	total: 1.37s	remaining: 270ms
# 167:	learn: 0.0226928	total: 1.38s	remaining: 263ms
# 168:	learn: 0.0224321	total: 1.39s	remaining: 255ms
# 169:	learn: 0.0222711	total: 1.4s	remaining: 247ms
# 170:	learn: 0.0220986	total: 1.41s	remaining: 238ms
# 171:	learn: 0.0218689	total: 1.41s	remaining: 230ms
# 172:	learn: 0.0216301	total: 1.42s	remaining: 222ms
# 173:	learn: 0.0213753	total: 1.43s	remaining: 213ms
# 174:	learn: 0.0212349	total: 1.44s	remaining: 206ms
# 175:	learn: 0.0210194	total: 1.45s	remaining: 198ms
# 176:	learn: 0.0208696	total: 1.46s	remaining: 190ms
# 177:	learn: 0.0206171	total: 1.47s	remaining: 182ms
# 178:	learn: 0.0204191	total: 1.48s	remaining: 174ms
# 179:	learn: 0.0202548	total: 1.49s	remaining: 166ms
# 180:	learn: 0.0201063	total: 1.51s	remaining: 158ms
# 181:	learn: 0.0199230	total: 1.52s	remaining: 150ms
# 182:	learn: 0.0197581	total: 1.53s	remaining: 142ms
# 183:	learn: 0.0195965	total: 1.54s	remaining: 134ms
# 184:	learn: 0.0194618	total: 1.55s	remaining: 126ms
# 185:	learn: 0.0193134	total: 1.56s	remaining: 117ms
# 186:	learn: 0.0192015	total: 1.57s	remaining: 109ms
# 187:	learn: 0.0190908	total: 1.58s	remaining: 101ms
# 188:	learn: 0.0189770	total: 1.59s	remaining: 92.3ms
# 189:	learn: 0.0189328	total: 1.59s	remaining: 83.8ms
# 190:	learn: 0.0187787	total: 1.6s	remaining: 75.3ms
# 191:	learn: 0.0186208	total: 1.6s	remaining: 66.8ms
# 192:	learn: 0.0184247	total: 1.61s	remaining: 58.4ms
# 193:	learn: 0.0182708	total: 1.62s	remaining: 50ms
# 194:	learn: 0.0181422	total: 1.62s	remaining: 41.6ms
# 195:	learn: 0.0179808	total: 1.63s	remaining: 33.2ms
# 196:	learn: 0.0178070	total: 1.63s	remaining: 24.9ms
# 197:	learn: 0.0176624	total: 1.64s	remaining: 16.6ms
# 198:	learn: 0.0175786	total: 1.65s	remaining: 8.28ms
# 199:	learn: 0.0174787	total: 1.65s	remaining: 0us
# Best Hyperparameters: {'border_count': 128, 'depth': 8, 'iterations': 200, 'l2_leaf_reg': 3, 'learning_rate': 0.1}
# Accuracy: 0.74757

# %%
best_params = grid_search.best_params_
final_xgb_clf = CatBoostClassifier(**best_params)
final_xgb_clf.fit(X_train, y_train)

# Make predictions on the test set
y_pred_proba_final = final_xgb_clf.predict_proba(X_test)[:, 1]

# Compute ROC AUC score
roc_auc_final = roc_auc_score(y_test, y_pred_proba_final)
print("Final ROC AUC score:", roc_auc_final)
# Out:
# 0:	learn: 0.6414715	total: 11.3ms	remaining: 2.24s
# 1:	learn: 0.5897174	total: 20.7ms	remaining: 2.05s
# 2:	learn: 0.5576135	total: 30.7ms	remaining: 2.02s
# 3:	learn: 0.5245553	total: 40ms	remaining: 1.96s
# 4:	learn: 0.5048667	total: 49ms	remaining: 1.91s
# 5:	learn: 0.4821132	total: 59.6ms	remaining: 1.93s
# 6:	learn: 0.4666344	total: 71.2ms	remaining: 1.96s
# 7:	learn: 0.4432706	total: 81.5ms	remaining: 1.95s
# 8:	learn: 0.4241402	total: 91.2ms	remaining: 1.94s
# 9:	learn: 0.4094466	total: 97.5ms	remaining: 1.85s
# 10:	learn: 0.3947041	total: 105ms	remaining: 1.8s
# 11:	learn: 0.3851821	total: 113ms	remaining: 1.76s
# 12:	learn: 0.3680709	total: 122ms	remaining: 1.75s
# 13:	learn: 0.3546043	total: 129ms	remaining: 1.71s
# 14:	learn: 0.3382709	total: 139ms	remaining: 1.71s
# 15:	learn: 0.3250368	total: 148ms	remaining: 1.7s
# 16:	learn: 0.3155018	total: 161ms	remaining: 1.73s
# 17:	learn: 0.3073458	total: 169ms	remaining: 1.71s
# 18:	learn: 0.2938923	total: 181ms	remaining: 1.72s
# 19:	learn: 0.2828936	total: 190ms	remaining: 1.71s
# 20:	learn: 0.2756567	total: 200ms	remaining: 1.71s
# 21:	learn: 0.2687469	total: 211ms	remaining: 1.71s
# 22:	learn: 0.2591120	total: 221ms	remaining: 1.7s
# 23:	learn: 0.2529230	total: 229ms	remaining: 1.68s
# 24:	learn: 0.2458878	total: 237ms	remaining: 1.66s
# 25:	learn: 0.2383706	total: 243ms	remaining: 1.63s
# 26:	learn: 0.2331885	total: 251ms	remaining: 1.6s
# 27:	learn: 0.2281785	total: 259ms	remaining: 1.59s
# 28:	learn: 0.2240049	total: 270ms	remaining: 1.59s
# 29:	learn: 0.2167594	total: 276ms	remaining: 1.56s
# 30:	learn: 0.2096263	total: 284ms	remaining: 1.55s
# 31:	learn: 0.2045769	total: 293ms	remaining: 1.54s
# 32:	learn: 0.1993412	total: 300ms	remaining: 1.52s
# 33:	learn: 0.1967287	total: 307ms	remaining: 1.5s
# 34:	learn: 0.1935504	total: 315ms	remaining: 1.48s
# 35:	learn: 0.1905784	total: 322ms	remaining: 1.47s
# 36:	learn: 0.1858356	total: 333ms	remaining: 1.47s
# 37:	learn: 0.1823626	total: 344ms	remaining: 1.46s
# 38:	learn: 0.1769441	total: 354ms	remaining: 1.46s
# 39:	learn: 0.1728184	total: 361ms	remaining: 1.45s
# 40:	learn: 0.1694429	total: 369ms	remaining: 1.43s
# 41:	learn: 0.1657740	total: 376ms	remaining: 1.41s
# 42:	learn: 0.1627024	total: 384ms	remaining: 1.4s
# 43:	learn: 0.1597701	total: 394ms	remaining: 1.4s
# 44:	learn: 0.1568477	total: 402ms	remaining: 1.38s
# 45:	learn: 0.1539229	total: 409ms	remaining: 1.37s
# 46:	learn: 0.1508843	total: 416ms	remaining: 1.35s
# 47:	learn: 0.1466386	total: 424ms	remaining: 1.34s
# 48:	learn: 0.1452192	total: 430ms	remaining: 1.33s
# 49:	learn: 0.1421802	total: 440ms	remaining: 1.32s
# 50:	learn: 0.1384874	total: 448ms	remaining: 1.31s
# 51:	learn: 0.1348230	total: 456ms	remaining: 1.3s
# 52:	learn: 0.1323699	total: 462ms	remaining: 1.28s
# 53:	learn: 0.1301843	total: 469ms	remaining: 1.27s
# 54:	learn: 0.1281072	total: 481ms	remaining: 1.27s
# 55:	learn: 0.1261667	total: 488ms	remaining: 1.25s
# 56:	learn: 0.1236145	total: 497ms	remaining: 1.25s
# 57:	learn: 0.1212931	total: 506ms	remaining: 1.24s
# 58:	learn: 0.1197410	total: 513ms	remaining: 1.23s
# 59:	learn: 0.1175645	total: 521ms	remaining: 1.22s
# 60:	learn: 0.1155198	total: 549ms	remaining: 1.25s
# 61:	learn: 0.1129876	total: 560ms	remaining: 1.25s
# 62:	learn: 0.1110535	total: 569ms	remaining: 1.24s
# 63:	learn: 0.1088450	total: 576ms	remaining: 1.22s
# 64:	learn: 0.1059702	total: 584ms	remaining: 1.21s
# 65:	learn: 0.1043828	total: 591ms	remaining: 1.2s
# 66:	learn: 0.1022559	total: 600ms	remaining: 1.19s
# 67:	learn: 0.1003052	total: 608ms	remaining: 1.18s
# 68:	learn: 0.0980851	total: 615ms	remaining: 1.17s
# 69:	learn: 0.0964813	total: 622ms	remaining: 1.15s
# 70:	learn: 0.0953261	total: 629ms	remaining: 1.14s
# 71:	learn: 0.0938500	total: 638ms	remaining: 1.13s
# 72:	learn: 0.0917911	total: 644ms	remaining: 1.12s
# 73:	learn: 0.0905014	total: 654ms	remaining: 1.11s
# 74:	learn: 0.0893042	total: 661ms	remaining: 1.1s
# 75:	learn: 0.0877146	total: 667ms	remaining: 1.09s
# 76:	learn: 0.0859979	total: 673ms	remaining: 1.07s
# 77:	learn: 0.0846004	total: 682ms	remaining: 1.07s
# 78:	learn: 0.0824482	total: 689ms	remaining: 1.05s
# 79:	learn: 0.0805444	total: 700ms	remaining: 1.05s
# 80:	learn: 0.0784587	total: 711ms	remaining: 1.04s
# 81:	learn: 0.0770759	total: 718ms	remaining: 1.03s
# 82:	learn: 0.0759037	total: 726ms	remaining: 1.02s
# 83:	learn: 0.0745845	total: 734ms	remaining: 1.01s
# 84:	learn: 0.0732926	total: 741ms	remaining: 1s
# 85:	learn: 0.0719568	total: 747ms	remaining: 990ms
# 86:	learn: 0.0707435	total: 754ms	remaining: 979ms
# 87:	learn: 0.0699670	total: 761ms	remaining: 968ms
# 88:	learn: 0.0687304	total: 768ms	remaining: 958ms
# 89:	learn: 0.0673691	total: 775ms	remaining: 947ms
# 90:	learn: 0.0659832	total: 785ms	remaining: 940ms
# 91:	learn: 0.0648193	total: 793ms	remaining: 931ms
# 92:	learn: 0.0637926	total: 800ms	remaining: 921ms
# 93:	learn: 0.0623172	total: 807ms	remaining: 911ms
# 94:	learn: 0.0615187	total: 815ms	remaining: 900ms
# 95:	learn: 0.0606881	total: 823ms	remaining: 892ms
# 96:	learn: 0.0600132	total: 833ms	remaining: 884ms
# 97:	learn: 0.0589375	total: 841ms	remaining: 875ms
# 98:	learn: 0.0578022	total: 849ms	remaining: 866ms
# 99:	learn: 0.0567362	total: 856ms	remaining: 856ms
# 100:	learn: 0.0558226	total: 864ms	remaining: 847ms
# 101:	learn: 0.0545881	total: 876ms	remaining: 842ms
# 102:	learn: 0.0536279	total: 887ms	remaining: 835ms
# 103:	learn: 0.0527276	total: 897ms	remaining: 828ms
# 104:	learn: 0.0519828	total: 905ms	remaining: 819ms
# 105:	learn: 0.0515011	total: 916ms	remaining: 812ms
# 106:	learn: 0.0505225	total: 924ms	remaining: 803ms
# 107:	learn: 0.0496296	total: 934ms	remaining: 796ms
# 108:	learn: 0.0486759	total: 955ms	remaining: 797ms
# 109:	learn: 0.0479414	total: 972ms	remaining: 795ms
# 110:	learn: 0.0472199	total: 980ms	remaining: 786ms
# 111:	learn: 0.0461821	total: 985ms	remaining: 774ms
# 112:	learn: 0.0454179	total: 993ms	remaining: 765ms
# 113:	learn: 0.0446062	total: 1s	remaining: 755ms
# 114:	learn: 0.0439505	total: 1.01s	remaining: 746ms
# 115:	learn: 0.0434384	total: 1.02s	remaining: 737ms
# 116:	learn: 0.0426311	total: 1.02s	remaining: 727ms
# 117:	learn: 0.0419754	total: 1.03s	remaining: 716ms
# 118:	learn: 0.0412874	total: 1.04s	remaining: 705ms
# 119:	learn: 0.0406706	total: 1.04s	remaining: 696ms
# 120:	learn: 0.0400134	total: 1.05s	remaining: 685ms
# 121:	learn: 0.0393869	total: 1.05s	remaining: 675ms
# 122:	learn: 0.0387831	total: 1.06s	remaining: 665ms
# 123:	learn: 0.0380955	total: 1.07s	remaining: 656ms
# 124:	learn: 0.0376414	total: 1.08s	remaining: 647ms
# 125:	learn: 0.0372512	total: 1.08s	remaining: 637ms
# 126:	learn: 0.0368501	total: 1.09s	remaining: 628ms
# 127:	learn: 0.0364914	total: 1.1s	remaining: 619ms
# 128:	learn: 0.0358990	total: 1.11s	remaining: 611ms
# 129:	learn: 0.0353692	total: 1.12s	remaining: 601ms
# 130:	learn: 0.0350922	total: 1.12s	remaining: 592ms
# 131:	learn: 0.0346283	total: 1.13s	remaining: 583ms
# 132:	learn: 0.0338733	total: 1.14s	remaining: 573ms
# 133:	learn: 0.0333833	total: 1.14s	remaining: 564ms
# 134:	learn: 0.0330436	total: 1.15s	remaining: 554ms
# 135:	learn: 0.0326930	total: 1.16s	remaining: 545ms
# 136:	learn: 0.0323439	total: 1.16s	remaining: 536ms
# 137:	learn: 0.0320021	total: 1.17s	remaining: 528ms
# 138:	learn: 0.0314953	total: 1.18s	remaining: 518ms
# 139:	learn: 0.0309556	total: 1.19s	remaining: 510ms
# 140:	learn: 0.0306455	total: 1.2s	remaining: 501ms
# 141:	learn: 0.0302913	total: 1.2s	remaining: 492ms
# 142:	learn: 0.0301087	total: 1.21s	remaining: 483ms
# 143:	learn: 0.0297524	total: 1.22s	remaining: 474ms
# 144:	learn: 0.0292805	total: 1.22s	remaining: 464ms
# 145:	learn: 0.0289145	total: 1.23s	remaining: 456ms
# 146:	learn: 0.0286047	total: 1.24s	remaining: 447ms
# 147:	learn: 0.0281104	total: 1.25s	remaining: 438ms
# 148:	learn: 0.0278246	total: 1.25s	remaining: 430ms
# 149:	learn: 0.0275794	total: 1.26s	remaining: 421ms
# 150:	learn: 0.0273867	total: 1.27s	remaining: 412ms
# 151:	learn: 0.0270099	total: 1.28s	remaining: 403ms
# 152:	learn: 0.0267259	total: 1.28s	remaining: 395ms
# 153:	learn: 0.0264372	total: 1.29s	remaining: 386ms
# 154:	learn: 0.0261555	total: 1.3s	remaining: 378ms
# 155:	learn: 0.0258244	total: 1.31s	remaining: 369ms
# 156:	learn: 0.0254828	total: 1.32s	remaining: 361ms
# 157:	learn: 0.0252342	total: 1.32s	remaining: 352ms
# 158:	learn: 0.0250506	total: 1.33s	remaining: 344ms
# 159:	learn: 0.0248189	total: 1.34s	remaining: 335ms
# 160:	learn: 0.0246278	total: 1.35s	remaining: 326ms
# 161:	learn: 0.0243551	total: 1.35s	remaining: 318ms
# 162:	learn: 0.0240804	total: 1.36s	remaining: 309ms
# 163:	learn: 0.0237671	total: 1.37s	remaining: 300ms
# 164:	learn: 0.0234275	total: 1.37s	remaining: 291ms
# 165:	learn: 0.0232144	total: 1.38s	remaining: 283ms
# 166:	learn: 0.0230025	total: 1.39s	remaining: 274ms
# 167:	learn: 0.0226928	total: 1.4s	remaining: 266ms
# 168:	learn: 0.0224321	total: 1.4s	remaining: 257ms
# 169:	learn: 0.0222711	total: 1.41s	remaining: 249ms
# 170:	learn: 0.0220986	total: 1.41s	remaining: 240ms
# 171:	learn: 0.0218689	total: 1.42s	remaining: 231ms
# 172:	learn: 0.0216301	total: 1.43s	remaining: 223ms
# 173:	learn: 0.0213753	total: 1.44s	remaining: 215ms
# 174:	learn: 0.0212349	total: 1.44s	remaining: 206ms
# 175:	learn: 0.0210194	total: 1.45s	remaining: 198ms
# 176:	learn: 0.0208696	total: 1.46s	remaining: 190ms
# 177:	learn: 0.0206171	total: 1.47s	remaining: 181ms
# 178:	learn: 0.0204191	total: 1.48s	remaining: 173ms
# 179:	learn: 0.0202548	total: 1.48s	remaining: 165ms
# 180:	learn: 0.0201063	total: 1.49s	remaining: 157ms
# 181:	learn: 0.0199230	total: 1.5s	remaining: 148ms
# 182:	learn: 0.0197581	total: 1.5s	remaining: 140ms
# 183:	learn: 0.0195965	total: 1.51s	remaining: 132ms
# 184:	learn: 0.0194618	total: 1.52s	remaining: 123ms
# 185:	learn: 0.0193134	total: 1.53s	remaining: 115ms
# 186:	learn: 0.0192015	total: 1.53s	remaining: 107ms
# 187:	learn: 0.0190908	total: 1.54s	remaining: 98.4ms
# 188:	learn: 0.0189770	total: 1.55s	remaining: 90.1ms
# 189:	learn: 0.0189328	total: 1.55s	remaining: 81.8ms
# 190:	learn: 0.0187787	total: 1.56s	remaining: 73.6ms
# 191:	learn: 0.0186208	total: 1.57s	remaining: 65.4ms
# 192:	learn: 0.0184247	total: 1.58s	remaining: 57.2ms
# 193:	learn: 0.0182708	total: 1.58s	remaining: 49ms
# 194:	learn: 0.0181422	total: 1.59s	remaining: 40.8ms
# 195:	learn: 0.0179808	total: 1.6s	remaining: 32.6ms
# 196:	learn: 0.0178070	total: 1.61s	remaining: 24.5ms
# 197:	learn: 0.0176624	total: 1.62s	remaining: 16.3ms
# 198:	learn: 0.0175786	total: 1.62s	remaining: 8.16ms
# 199:	learn: 0.0174787	total: 1.63s	remaining: 0us
# Final ROC AUC score: 0.6589869281045752

# %%
X_train.columns
# Out:
# Index(['height_cm', 'weight_kg', 'work_rate_numeric', 'pace', 'physic',
#        'position_numeric', 'age', 'cumulative_minutes_played',
#        'minutes_per_game_prev_seasons', 'avg_days_injured_prev_seasons',
#        'significant_injury_prev_season', 'cumulative_days_injured'],
#       dtype='object')

# %% [markdown]
# # roc curve

# %%
from sklearn.metrics import roc_auc_score, roc_curve
import xgboost as xgb
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier


# Create and fit the XGBoost model
xgb_model = xgb.XGBClassifier(colsample_bytree = 1.0, gamma=0.2, learning_rate= 0.2, max_depth= 5, min_child_weight= 1, n_estimators= 100, scale_pos_weight=1, subsample= 0.8)
xgb_model.fit(X_train, y_train)
xgb_probs = xgb_model.predict_proba(X_test)[:, 1]
xgb_auc = roc_auc_score(y_test, xgb_probs)


# Create and fit the K-Nearest Neighbors model
knn_model = KNeighborsClassifier(metric= 'manhattan', n_neighbors= 7, weights= 'distance')
knn_model.fit(X_train, y_train)
knn_probs = knn_model.predict_proba(X_test)[:, 1]
knn_auc = roc_auc_score(y_test, knn_probs)

# Create and fit the Decision Tree model
dt_model = DecisionTreeClassifier(criterion= 'entropy', max_depth= 15, max_features= 'log2', min_samples_leaf= 2, min_samples_split= 5)
dt_model.fit(X_train, y_train)
dt_probs = dt_model.predict_proba(X_test)[:, 1]
dt_auc = roc_auc_score(y_test, dt_probs)

# Create and fit the random forest model
rf_model = RandomForestClassifier(max_depth= 20, max_features= 'sqrt', min_samples_leaf= 1, min_samples_split= 2, n_estimators= 100)
rf_model.fit(X_train, y_train)
rf_probs = rf_model.predict_proba(X_test)[:, 1]
rf_auc = roc_auc_score(y_test, rf_probs)

# Create and fit the CatBoost model
catboost_model = CatBoostClassifier(border_count= 128, depth= 8, iterations=200, l2_leaf_reg= 3, learning_rate= 0.1)
catboost_model.fit(X_train, y_train)
catboost_probs = catboost_model.predict_proba(X_test)[:, 1]
catboost_auc = roc_auc_score(y_test, catboost_probs)

# Continue with the existing code for CatBoost, Random Forest, and plotting ROC curves

# Print AUC scores for all models
print(f"CatBoost AUC: {catboost_auc:.5f}")
print(f"KNN AUC: {knn_auc:.5f}")
#print(f"XGBoost AUC: {xgb_auc:.5f}")
print(f"Decision Tree AUC: {dt_auc:.5f}")
print(f"Random Forest AUC: {rf_auc:.5f}")

# Continue with the existing code for plotting ROC curves
# Out:
# 0:	learn: 0.6414715	total: 7.62ms	remaining: 1.51s
# 1:	learn: 0.5897174	total: 16ms	remaining: 1.58s
# 2:	learn: 0.5576135	total: 23.4ms	remaining: 1.53s
# 3:	learn: 0.5245553	total: 30.4ms	remaining: 1.49s
# 4:	learn: 0.5048667	total: 38.4ms	remaining: 1.5s
# 5:	learn: 0.4821132	total: 46.5ms	remaining: 1.5s
# 6:	learn: 0.4666344	total: 51.5ms	remaining: 1.42s
# 7:	learn: 0.4432706	total: 57.1ms	remaining: 1.37s
# 8:	learn: 0.4241402	total: 63.1ms	remaining: 1.34s
# 9:	learn: 0.4094466	total: 69ms	remaining: 1.31s
# 10:	learn: 0.3947041	total: 75.4ms	remaining: 1.29s
# 11:	learn: 0.3851821	total: 81.1ms	remaining: 1.27s
# 12:	learn: 0.3680709	total: 86.3ms	remaining: 1.24s
# 13:	learn: 0.3546043	total: 93ms	remaining: 1.24s
# 14:	learn: 0.3382709	total: 98.1ms	remaining: 1.21s
# 15:	learn: 0.3250368	total: 105ms	remaining: 1.2s
# 16:	learn: 0.3155018	total: 111ms	remaining: 1.19s
# 17:	learn: 0.3073458	total: 116ms	remaining: 1.17s
# 18:	learn: 0.2938923	total: 122ms	remaining: 1.16s
# 19:	learn: 0.2828936	total: 127ms	remaining: 1.15s
# 20:	learn: 0.2756567	total: 133ms	remaining: 1.13s
# 21:	learn: 0.2687469	total: 139ms	remaining: 1.12s
# 22:	learn: 0.2591120	total: 144ms	remaining: 1.11s
# 23:	learn: 0.2529230	total: 149ms	remaining: 1.09s
# 24:	learn: 0.2458878	total: 156ms	remaining: 1.09s
# 25:	learn: 0.2383706	total: 161ms	remaining: 1.08s
# 26:	learn: 0.2331885	total: 166ms	remaining: 1.07s
# 27:	learn: 0.2281785	total: 172ms	remaining: 1.06s
# 28:	learn: 0.2240049	total: 178ms	remaining: 1.05s
# 29:	learn: 0.2167594	total: 183ms	remaining: 1.04s
# 30:	learn: 0.2096263	total: 189ms	remaining: 1.03s
# 31:	learn: 0.2045769	total: 196ms	remaining: 1.03s
# 32:	learn: 0.1993412	total: 205ms	remaining: 1.04s
# 33:	learn: 0.1967287	total: 211ms	remaining: 1.03s
# 34:	learn: 0.1935504	total: 216ms	remaining: 1.02s
# 35:	learn: 0.1905784	total: 223ms	remaining: 1.01s
# 36:	learn: 0.1858356	total: 228ms	remaining: 1s
# 37:	learn: 0.1823626	total: 235ms	remaining: 1s
# 38:	learn: 0.1769441	total: 241ms	remaining: 995ms
# 39:	learn: 0.1728184	total: 248ms	remaining: 992ms
# 40:	learn: 0.1694429	total: 253ms	remaining: 983ms
# 41:	learn: 0.1657740	total: 259ms	remaining: 973ms
# 42:	learn: 0.1627024	total: 264ms	remaining: 966ms
# 43:	learn: 0.1597701	total: 270ms	remaining: 957ms
# 44:	learn: 0.1568477	total: 275ms	remaining: 948ms
# 45:	learn: 0.1539229	total: 283ms	remaining: 948ms
# 46:	learn: 0.1508843	total: 288ms	remaining: 939ms
# 47:	learn: 0.1466386	total: 293ms	remaining: 929ms
# 48:	learn: 0.1452192	total: 300ms	remaining: 923ms
# 49:	learn: 0.1421802	total: 305ms	remaining: 915ms
# 50:	learn: 0.1384874	total: 311ms	remaining: 909ms
# 51:	learn: 0.1348230	total: 317ms	remaining: 901ms
# 52:	learn: 0.1323699	total: 322ms	remaining: 893ms
# 53:	learn: 0.1301843	total: 328ms	remaining: 888ms
# 54:	learn: 0.1281072	total: 334ms	remaining: 881ms
# 55:	learn: 0.1261667	total: 339ms	remaining: 873ms
# 56:	learn: 0.1236145	total: 346ms	remaining: 869ms
# 57:	learn: 0.1212931	total: 351ms	remaining: 860ms
# 58:	learn: 0.1197410	total: 357ms	remaining: 854ms
# 59:	learn: 0.1175645	total: 363ms	remaining: 847ms
# 60:	learn: 0.1155198	total: 368ms	remaining: 839ms
# 61:	learn: 0.1129876	total: 377ms	remaining: 839ms
# 62:	learn: 0.1110535	total: 386ms	remaining: 839ms
# 63:	learn: 0.1088450	total: 395ms	remaining: 838ms
# 64:	learn: 0.1059702	total: 400ms	remaining: 831ms
# 65:	learn: 0.1043828	total: 407ms	remaining: 826ms
# 66:	learn: 0.1022559	total: 411ms	remaining: 817ms
# 67:	learn: 0.1003052	total: 417ms	remaining: 810ms
# 68:	learn: 0.0980851	total: 424ms	remaining: 806ms
# 69:	learn: 0.0964813	total: 430ms	remaining: 798ms
# 70:	learn: 0.0953261	total: 436ms	remaining: 792ms
# 71:	learn: 0.0938500	total: 442ms	remaining: 785ms
# 72:	learn: 0.0917911	total: 447ms	remaining: 778ms
# 73:	learn: 0.0905014	total: 454ms	remaining: 773ms
# 74:	learn: 0.0893042	total: 460ms	remaining: 767ms
# 75:	learn: 0.0877146	total: 465ms	remaining: 758ms
# 76:	learn: 0.0859979	total: 473ms	remaining: 756ms
# 77:	learn: 0.0846004	total: 479ms	remaining: 749ms
# 78:	learn: 0.0824482	total: 485ms	remaining: 743ms
# 79:	learn: 0.0805444	total: 491ms	remaining: 737ms
# 80:	learn: 0.0784587	total: 497ms	remaining: 730ms
# 81:	learn: 0.0770759	total: 504ms	remaining: 725ms
# 82:	learn: 0.0759037	total: 509ms	remaining: 718ms
# 83:	learn: 0.0745845	total: 515ms	remaining: 712ms
# 84:	learn: 0.0732926	total: 523ms	remaining: 708ms
# 85:	learn: 0.0719568	total: 529ms	remaining: 701ms
# 86:	learn: 0.0707435	total: 536ms	remaining: 696ms
# 87:	learn: 0.0699670	total: 542ms	remaining: 690ms
# 88:	learn: 0.0687304	total: 547ms	remaining: 682ms
# 89:	learn: 0.0673691	total: 555ms	remaining: 679ms
# 90:	learn: 0.0659832	total: 563ms	remaining: 674ms
# 91:	learn: 0.0648193	total: 570ms	remaining: 669ms
# 92:	learn: 0.0637926	total: 576ms	remaining: 662ms
# 93:	learn: 0.0623172	total: 585ms	remaining: 660ms
# 94:	learn: 0.0615187	total: 591ms	remaining: 654ms
# 95:	learn: 0.0606881	total: 597ms	remaining: 647ms
# 96:	learn: 0.0600132	total: 603ms	remaining: 641ms
# 97:	learn: 0.0589375	total: 610ms	remaining: 634ms
# 98:	learn: 0.0578022	total: 617ms	remaining: 630ms
# 99:	learn: 0.0567362	total: 622ms	remaining: 622ms
# 100:	learn: 0.0558226	total: 629ms	remaining: 616ms
# 101:	learn: 0.0545881	total: 634ms	remaining: 609ms
# 102:	learn: 0.0536279	total: 639ms	remaining: 602ms
# 103:	learn: 0.0527276	total: 645ms	remaining: 596ms
# 104:	learn: 0.0519828	total: 651ms	remaining: 589ms
# 105:	learn: 0.0515011	total: 656ms	remaining: 582ms
# 106:	learn: 0.0505225	total: 663ms	remaining: 576ms
# 107:	learn: 0.0496296	total: 668ms	remaining: 569ms
# 108:	learn: 0.0486759	total: 674ms	remaining: 562ms
# 109:	learn: 0.0479414	total: 680ms	remaining: 557ms
# 110:	learn: 0.0472199	total: 685ms	remaining: 550ms
# 111:	learn: 0.0461821	total: 691ms	remaining: 543ms
# 112:	learn: 0.0454179	total: 697ms	remaining: 537ms
# 113:	learn: 0.0446062	total: 703ms	remaining: 531ms
# 114:	learn: 0.0439505	total: 710ms	remaining: 524ms
# 115:	learn: 0.0434384	total: 715ms	remaining: 518ms
# 116:	learn: 0.0426311	total: 720ms	remaining: 511ms
# 117:	learn: 0.0419754	total: 726ms	remaining: 505ms
# 118:	learn: 0.0412874	total: 733ms	remaining: 499ms
# 119:	learn: 0.0406706	total: 741ms	remaining: 494ms
# 120:	learn: 0.0400134	total: 748ms	remaining: 488ms
# 121:	learn: 0.0393869	total: 780ms	remaining: 499ms
# 122:	learn: 0.0387831	total: 791ms	remaining: 495ms
# 123:	learn: 0.0380955	total: 799ms	remaining: 490ms
# 124:	learn: 0.0376414	total: 807ms	remaining: 484ms
# 125:	learn: 0.0372512	total: 814ms	remaining: 478ms
# 126:	learn: 0.0368501	total: 822ms	remaining: 472ms
# 127:	learn: 0.0364914	total: 830ms	remaining: 467ms
# 128:	learn: 0.0358990	total: 838ms	remaining: 461ms
# 129:	learn: 0.0353692	total: 846ms	remaining: 456ms
# 130:	learn: 0.0350922	total: 855ms	remaining: 451ms
# 131:	learn: 0.0346283	total: 864ms	remaining: 445ms
# 132:	learn: 0.0338733	total: 874ms	remaining: 440ms
# 133:	learn: 0.0333833	total: 884ms	remaining: 435ms
# 134:	learn: 0.0330436	total: 896ms	remaining: 431ms
# 135:	learn: 0.0326930	total: 905ms	remaining: 426ms
# 136:	learn: 0.0323439	total: 914ms	remaining: 421ms
# 137:	learn: 0.0320021	total: 925ms	remaining: 416ms
# 138:	learn: 0.0314953	total: 933ms	remaining: 409ms
# 139:	learn: 0.0309556	total: 940ms	remaining: 403ms
# 140:	learn: 0.0306455	total: 947ms	remaining: 396ms
# 141:	learn: 0.0302913	total: 955ms	remaining: 390ms
# 142:	learn: 0.0301087	total: 963ms	remaining: 384ms
# 143:	learn: 0.0297524	total: 971ms	remaining: 377ms
# 144:	learn: 0.0292805	total: 978ms	remaining: 371ms
# 145:	learn: 0.0289145	total: 986ms	remaining: 365ms
# 146:	learn: 0.0286047	total: 993ms	remaining: 358ms
# 147:	learn: 0.0281104	total: 1s	remaining: 352ms
# 148:	learn: 0.0278246	total: 1.01s	remaining: 345ms
# 149:	learn: 0.0275794	total: 1.01s	remaining: 339ms
# 150:	learn: 0.0273867	total: 1.02s	remaining: 332ms
# 151:	learn: 0.0270099	total: 1.03s	remaining: 326ms
# 152:	learn: 0.0267259	total: 1.04s	remaining: 319ms
# 153:	learn: 0.0264372	total: 1.04s	remaining: 312ms
# 154:	learn: 0.0261555	total: 1.05s	remaining: 305ms
# 155:	learn: 0.0258244	total: 1.06s	remaining: 298ms
# 156:	learn: 0.0254828	total: 1.07s	remaining: 292ms
# 157:	learn: 0.0252342	total: 1.07s	remaining: 285ms
# 158:	learn: 0.0250506	total: 1.08s	remaining: 279ms
# 159:	learn: 0.0248189	total: 1.09s	remaining: 273ms
# 160:	learn: 0.0246278	total: 1.1s	remaining: 267ms
# 161:	learn: 0.0243551	total: 1.15s	remaining: 269ms
# 162:	learn: 0.0240804	total: 1.17s	remaining: 265ms
# 163:	learn: 0.0237671	total: 1.18s	remaining: 259ms
# 164:	learn: 0.0234275	total: 1.19s	remaining: 251ms
# 165:	learn: 0.0232144	total: 1.2s	remaining: 245ms
# 166:	learn: 0.0230025	total: 1.2s	remaining: 238ms
# 167:	learn: 0.0226928	total: 1.21s	remaining: 231ms
# 168:	learn: 0.0224321	total: 1.22s	remaining: 224ms
# 169:	learn: 0.0222711	total: 1.23s	remaining: 217ms
# 170:	learn: 0.0220986	total: 1.24s	remaining: 210ms
# 171:	learn: 0.0218689	total: 1.25s	remaining: 203ms
# 172:	learn: 0.0216301	total: 1.25s	remaining: 196ms
# 173:	learn: 0.0213753	total: 1.26s	remaining: 189ms
# 174:	learn: 0.0212349	total: 1.27s	remaining: 181ms
# 175:	learn: 0.0210194	total: 1.27s	remaining: 174ms
# 176:	learn: 0.0208696	total: 1.28s	remaining: 167ms
# 177:	learn: 0.0206171	total: 1.29s	remaining: 159ms
# 178:	learn: 0.0204191	total: 1.3s	remaining: 152ms
# 179:	learn: 0.0202548	total: 1.3s	remaining: 145ms
# 180:	learn: 0.0201063	total: 1.31s	remaining: 138ms
# 181:	learn: 0.0199230	total: 1.32s	remaining: 130ms
# 182:	learn: 0.0197581	total: 1.32s	remaining: 123ms
# 183:	learn: 0.0195965	total: 1.33s	remaining: 116ms
# 184:	learn: 0.0194618	total: 1.34s	remaining: 109ms
# 185:	learn: 0.0193134	total: 1.34s	remaining: 101ms
# 186:	learn: 0.0192015	total: 1.35s	remaining: 94ms
# 187:	learn: 0.0190908	total: 1.36s	remaining: 86.8ms
# 188:	learn: 0.0189770	total: 1.37s	remaining: 79.7ms
# 189:	learn: 0.0189328	total: 1.38s	remaining: 72.5ms
# 190:	learn: 0.0187787	total: 1.38s	remaining: 65.2ms
# 191:	learn: 0.0186208	total: 1.39s	remaining: 57.9ms
# 192:	learn: 0.0184247	total: 1.4s	remaining: 50.7ms
# 193:	learn: 0.0182708	total: 1.41s	remaining: 43.5ms
# 194:	learn: 0.0181422	total: 1.41s	remaining: 36.2ms
# 195:	learn: 0.0179808	total: 1.42s	remaining: 28.9ms
# 196:	learn: 0.0178070	total: 1.43s	remaining: 21.7ms
# 197:	learn: 0.0176624	total: 1.43s	remaining: 14.5ms
# 198:	learn: 0.0175786	total: 1.44s	remaining: 7.23ms
# 199:	learn: 0.0174787	total: 1.45s	remaining: 0us
# CatBoost AUC: 0.65899
# KNN AUC: 0.70114
# Decision Tree AUC: 0.56250
# Random Forest AUC: 0.65008

# %%
# from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

# Assuming you have xgb_probs, knn_probs, dt_probs, rf_probs, catboost_probs already calculated

# Create an ROC curve for each classifier
fpr_xgb, tpr_xgb, _ = roc_curve(y_test, xgb_probs)
fpr_knn, tpr_knn, _ = roc_curve(y_test, knn_probs)
fpr_dt, tpr_dt, _ = roc_curve(y_test, dt_probs)
fpr_rf, tpr_rf, _ = roc_curve(y_test, rf_probs)
fpr_catboost, tpr_catboost, _ = roc_curve(y_test, catboost_probs)

# Calculate AUC for each classifier
auc_xgb = auc(fpr_xgb, tpr_xgb)
auc_knn = auc(fpr_knn, tpr_knn)
auc_dt = auc(fpr_dt, tpr_dt)
auc_rf = auc(fpr_rf, tpr_rf)
auc_catboost = auc(fpr_catboost, tpr_catboost)

# Plot ROC curves
plt.figure(figsize=(8, 8))
plt.plot(fpr_xgb, tpr_xgb, label=f'XGBoost (AUC = {auc_xgb:.3f})')
plt.plot(fpr_knn, tpr_knn, label=f'KNN (AUC = {auc_knn:.3f})')
plt.plot(fpr_dt, tpr_dt, label=f'Decision Tree (AUC = {auc_dt:.3f})')
plt.plot(fpr_rf, tpr_rf, label=f'Random Forest (AUC = {auc_rf:.3f})')
plt.plot(fpr_catboost, tpr_catboost, label=f'CatBoost (AUC = {auc_catboost:.3f})')

# Plot the diagonal line (random classifier)
plt.plot([0, 1], [0, 1], linestyle='--', color='gray', label='Random')

# Set plot labels and title
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend()
plt.show()

# %%
'''
import pickle

model = KNeighborsClassifier()
model.fit(X_train, y_train)

# Save the model to a file using pickle
with open('knn_model.pkl', 'wb') as file:
    pickle.dump(model, file)

# Load the model from the file
with open('knn_model.pkl', 'rb') as file:
    loaded_model = pickle.load(file)

# Now, you can use the loaded_model for predictions

'''
# Out:
# "\nimport pickle\n\nmodel = KNeighborsClassifier()\nmodel.fit(X_train, y_train)\n\n# Save the model to a file using pickle\nwith open('knn_model.pkl', 'wb') as file:\n    pickle.dump(model, file)\n\n# Load the model from the file\nwith open('knn_model.pkl', 'rb') as file:\n    loaded_model = pickle.load(file)\n\n# Now, you can use the loaded_model for predictions\n\n"
